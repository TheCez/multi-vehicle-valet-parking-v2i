# %%
import commonroad_reach.utility.logger as util_logger
from commonroad_reach.data_structure.configuration_builder import ConfigurationBuilder
from commonroad_reach.data_structure.reach.reach_interface import ReachableSetInterface
from commonroad_reach.utility import visualization as util_visual

# %%
# Create a base configuration with default values
def create_base_configuration():
    # ==== specify scenario
    name_scenario = "ZAM_MUC-1"

    # ==== build configuration
    config = ConfigurationBuilder(path_root="..").build_configuration(name_scenario)
    #config.update()
    logger = util_logger.initialize_logger(config)
    #config.print_configuration_summary()
    return config, logger

# %%
config, logger = create_base_configuration()
config.print_configuration_summary()
# Out:
# # ===== CommonRoad-Reach Configuration Builder ===== #
# # Root path:
# # 	..
# # Using default configs from:
# # 	/home/thecez/thesis/commonroad-scene/.venv/lib/python3.10/site-packages/commonroad_reach/configurations_default
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 config, logger = create_base_configuration()
#       2 config.print_configuration_summary()
#
# Cell In[9], line 9, in create_base_configuration()
#       7 config = ConfigurationBuilder(path_root="..").build_configuration(name_scenario)
#       8 #config.update()
# ----> 9 logger = util_logger.initialize_logger(config)
#      10 #config.print_configuration_summary()
#      11 return config, logger
#
# File ~/thesis/commonroad-scene/.venv/lib/python3.10/site-packages/commonroad_reach/utility/logger.py:18, in initialize_logger(config)
#      16 # create file handler (outputs to file)
#      17 string_date_time = datetime.now().strftime("_%Y_%m_%d_%H-%M-%S")
# ---> 18 path_log = os.path.join(config.general.path_logs, f"{config.scenario.scenario_id}{string_date_time}.log")
#      19 file_handler = logging.FileHandler(path_log)
#      21 # set logging levels
#
# AttributeError: 'NoneType' object has no attribute 'scenario_id'
